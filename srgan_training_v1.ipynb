# %%
from pathlib import Path
root_path = Path("/home/ubuntu/sr")

# %%
assert(root_path.exists())

# %%
# %load_ext autoreload
# %autoreload 2
from srgan.train import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
train(root_path)
# Out:
# cuda
# /home/ubuntu/sr/model_checkpoint/aishu/srgan_v0.pth
# checkpoint exists... loading...
# Generator: 1549462
# Discriminator: 23565505
# Length of train loader: 15
# ...
#
# VGG loss 0.381014 (0.266376)
# Adversarial loss(G) 0.000000 (0.000000)
# Adversarial loss(D) 1526.808716 (1749.432978)
#
# ...
#
#
# ...
#
# VGG loss 0.284561 (0.257898)
# Adversarial loss(G) 0.000000 (0.000000)
# Adversarial loss(D) 1303.068726 (1608.529239)
#
# ...
#
#
# ...
#
# VGG loss 0.214992 (0.252662)
# Adversarial loss(G) 0.000000 (0.000000)
# Adversarial loss(D) 1053.240479 (1473.077708)
#
# ...
#
#
# ...
#
# VGG loss 0.274008 (0.248874)
# Adversarial loss(G) 2.277565 (0.059153)
# Adversarial loss(D) 956.182312 (1343.729622)
#
# ...
#
#
# ...
#
# VGG loss 0.266698 (0.248481)
# Adversarial loss(G) 2.136349 (0.341750)
# Adversarial loss(D) 922.349915 (1247.712197)
#
# ...
#
#
# ...
#
# VGG loss 0.181554 (0.246760)
# Adversarial loss(G) 3.204141 (0.471919)
# Adversarial loss(D) 848.455139 (1179.450160)
#
# ...
#
#
# ...
#
# VGG loss 0.232439 (0.246472)
# ...

# %%
! ls
