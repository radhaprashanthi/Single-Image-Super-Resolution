# %%
from pathlib import Path
root_path = Path("/home/ubuntu/sr")

# %%
assert(root_path.exists())

# %%
# %load_ext autoreload
# %autoreload 2
from srgan.train import *

# %%
train(root_path)
# Out:
# cuda
# /home/ubuntu/sr/model_checkpoint/aishu/srgan_v0.pth /home/ubuntu/sr/model_checkpoint/aishu/srgan_best.pth
# checkpoint exists... loading...
# Generator: 1549462
# Discriminator: 23565505
# Length of train loader: 20
# ...
#
# VGG loss 0.279637 (0.273684)
# Adversarial loss(G) 0.000000 (0.119324)
# Adversarial loss(D) 972.425476 (891.986766)
#
# ...
#
# better loss, saving the gan
#
# ...
#
# VGG loss 0.335784 (0.256978)
# Adversarial loss(G) 0.000000 (1.067597)
# Adversarial loss(D) 749.598145 (855.612068)
#
# ...
#
#
# ...
#
# VGG loss 0.284697 (0.254557)
# Adversarial loss(G) 0.000000 (1.198721)
# Adversarial loss(D) 950.684509 (883.372712)
#
# ...
#
#
# ...
#
# VGG loss 0.173547 (0.250077)
# Adversarial loss(G) 0.000000 (1.061561)
# Adversarial loss(D) 991.313354 (875.967461)
#
# ...
#
# better loss, saving the gan
#
# ...
#
# VGG loss 0.181282 (0.247558)
# Adversarial loss(G) 20.925707 (1.132465)
# Adversarial loss(D) 466.814240 (802.798514)
#
# ...
#
#
# ...
#
# VGG loss 0.280249 (0.246880)
# Adversarial loss(G) 2.025515 (1.125936)
# ...

# %%
! cp ~/sr/model_checkpoint/aishu/srgan_best.pth ~/sr/model_checkpoint/aishu/srgan_best_latest.pth
! cp ~/sr/model_checkpoint/aishu/srgan_v0.pth ~/sr/model_checkpoint/aishu/srgan_vo_latest.pth

! cp ~/sr/model_checkpoint/aishu/srgan_v0.pth ~/sr/model_checkpoint/aishu/srgan_best.pth

# %%
! ls ~/sr/model_checkpoint/aishu/ -lh
# Out:
# total 672M
# -rw-rw-r-- 1 ubuntu ubuntu 96M Jun 22 22:05 pretrained_srgan.pth
# -rw-rw-r-- 1 ubuntu ubuntu 96M Jun 24 12:15 srgan_best_latest.pth
# -rw-rw-r-- 1 ubuntu ubuntu 96M Jun 24 12:15 srgan_best.pth
# -rw-rw-r-- 1 ubuntu ubuntu 96M Jun 24 06:59 srgan_v0_2306_latest.pth
# -rw-rw-r-- 1 ubuntu ubuntu 96M Jun 23 03:36 srgan_v0_latest.pth
# -rw-rw-r-- 1 ubuntu ubuntu 96M Jun 24 12:15 srgan_v0.pth
# -rw-rw-r-- 1 ubuntu ubuntu 96M Jun 24 12:15 srgan_vo_latest.pth

# %%
train(root_path)
# Out:
# cuda
# /home/ubuntu/sr/model_checkpoint/aishu/srgan_v0.pth /home/ubuntu/sr/model_checkpoint/aishu/srgan_best.pth
# checkpoint exists... loading...
# Generator: 1549462
# Discriminator: 23565505
# Length of train loader: 20
# ...
#
# VGG loss 0.327546 (0.230927)
# Adversarial loss(G) 25.028194 (3.239498)
# Adversarial loss(D) 10.825170 (3.033226)
#
# ...
#
# better loss, saving the gan
#
# ...
#
# VGG loss 0.213923 (0.232601)
# Adversarial loss(G) 5.639206 (2.669293)
# Adversarial loss(D) 1.184607 (2.891517)
#
# ...
#
# better loss, saving the gan
#
# ...
#
# VGG loss 0.235870 (0.230288)
# Adversarial loss(G) 0.001752 (2.564060)
# Adversarial loss(D) 28.572681 (6.006446)
#
# ...
#
#
# ...
#
# VGG loss 0.254556 (0.228701)
# Adversarial loss(G) 7.114256 (2.868004)
# Adversarial loss(D) 26.762711 (7.790634)
#
# ...
#
#
# ...
#
# VGG loss 0.261253 (0.229047)
# Adversarial loss(G) 18.818832 (3.291251)
# Adversarial loss(D) 8.214937 (9.495676)
#
# ...
#
#
# ...
#
# VGG loss 0.278341 (0.229356)
# Adversarial loss(G) 9.945415 (3.936208)
# ...
